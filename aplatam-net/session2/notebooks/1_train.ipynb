# %% [markdown]
# # 1_Train
#
#    El modelo de ML utiliza para entrenar un dataset compuesto por imágenes y máscaras para el entrenamiento. Estas ultimas son imagenes binarias que delimitan el objeto de interés, 1 donde esta y 0 donde no.

# %%
#!pip install pysatproc unetseg

# %%
from unetseg.train import TrainConfig, train
from unetseg.evaluate import plot_data_generator
import os
# Out:
# 2022-07-12 19:20:10.756591: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
#General
BUCKET_TRAIN = "gs://dym-workshops-public/session2//informal-settlements-sentinel2-RGBNIR/imagenes/"
BUCKET_DATA  = "gs://dym-workshops-public/session2//informal-settlements-sentinel2-RGBNIR/data"

BASE_PATH         = "./../"
PATH_TRAIN_IMAGES = f'/images_sentinel2_RGBNIR/'

GT_FILE        = "informal_settlements_all.gpkg"
AOI_TRAIN_FILE = "informal_settlements_epsg4326_claseA_buff2000_dissolve.gpkg"


STEP_PER_EPOCH = 650

SIZE      = 160 
STEP_SIZE = 160

INFO = "v0"
MODEL_NAME = f'UNet_160x160_sentinel2_4D_classA_{INFO}.h5'

BUCKET_MODEL = f"gs://dym-workshops-public/session2//informal-settlements-sentinel2-RGBNIR/data/weights/"

# %% [markdown]
#
# ## Generacion del data set de entrenamiento
#
#    En esta etapa generamos el dataset de entrenamiento mediante el uso de **GDAL** y **Satproc**. Primero descargamos las imagenes satelitales y utilizamos GDAL para quedarnos con la combinacion de bandas deseada. Luego Utilizamos satproc para generar el dataset con todas las caracteristicas necesarias para el modelo: tamaño , cantidad de imagenes, rango de valores, etc.

# %% [markdown]
# Descargamos las imágenes del bucket

# %%
folder = BASE_PATH + PATH_TRAIN_IMAGES

# %%
#download images
# !mkdir -p $folder
# !gsutil -m cp -r $BUCKET_TRAIN   $folder 
#dounload vector f
# !gsutil -m cp -r $BUCKET_DATA   $BASE_PATH

# %% [markdown]
# Podemos verificar que los archivos fueron correctamente descargados

# %%
# !ls $folder
# Out:
# imagenes

# %% [markdown]
# ### Satproc
#
# Con la herramienta **satproc_extract_chips** se generan, a partir de las imágenes descargadas del bucket, imágenes (chips) generalmente mas pequeñas y máscaras (utilizando las anotaciones de verdad de campo).

# %% [markdown]
# **OBS** : tanto las imagenes como el archivo vectorial deben tener la misma georeferencia, por ejemplo 4326

# %%
path_to_files   = f'{folder}/*/*/*tif' #carpeta a las imagenes
output_folder   = f'{BASE_PATH}/dataset/data_train/{str(SIZE)}_{str(STEP_SIZE)}/' #carpeta de destino del dataset
vector_file     = f'{BASE_PATH}/data/shp/gt/{GT_FILE}' # archivo vectorial de verdad de campo
vector_file_aoi = f'{BASE_PATH}/data/shp/{AOI_TRAIN_FILE}' #archivo vectorial con las zonas de interes

# %% [markdown]
# Ejecutamos satproc

# %%
#!satproc_extract_chips --help

# %%
# !satproc_extract_chips \
                $path_to_files \
                -o  $output_folder \
                --size $SIZE \
                --step-size $STEP_SIZE \
                --aoi $vector_file_aoi \
                --labels $vector_file \
                --label-property 'class' \
                --skip-low-contrast \
                --classes 'A' \
                --rescale \
                --rescale-mode s2_rgb_extra --lower-cut 1 --upper-cut 100
# Out:
# Rasters:   0%|                                          | 0/361 [00:00<?, ?it/s]
# arg_2016_1.tif windows:   0%|                            | 0/16 [00:00<?, ?it/s]/opt/miniconda3/envs/tf-gpu/lib/python3.8/site-packages/rasterio/features.py:318: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 
# per_2018_1.tif windows:  50%|##########          | 8/16 [00:03<00:03,  2.50it/s]
# per_2018_1.tif windows:  56%|###########2        | 9/16 [00:03<00:02,  2.49it/s]
# per_2018_1.tif windows:  62%|###########8       | 10/16 [00:03<00:02,  2.51it/s]
# per_2018_1.tif windows:  69%|#############      | 11/16 [00:04<00:02,  2.50it/s]
# per_2018_1.tif windows:  75%|##############2    | 12/16 [00:04<00:01,  2.48it/s]
# per_2018_1.tif windows:  81%|###############4   | 13/16 [00:05<00:01,  2.46it/s]
# per_2018_1.tif windows:  88%|################6  | 14/16 [00:05<00:00,  2.53it/s]
# per_2018_1.tif windows:  94%|#################8 | 15/16 [00:05<00:00,  2.53it/s]
# per_2018_1.tif windows: 100%|###################| 16/16 [00:06<00:00,  2.51it/s]
# Rasters: 100%|##############################| 361/361 [1:18:48<00:00, 13.10s/it]

# %% [markdown]
# ###### Los argumentos:
#
# * **path_to_files** es la ruta a las imágenes
#
# * **o** es la ruta de destino
#
# Recomendamos que dicha ruta sea descriptiva, por ejemplo “data_train/120_40/ ” describe : Data_train → datos usados para entrenar; 120_40 → <tamaño de la imagen >_ <tamaño del step-size>
#
# * **size** tamaño de las imágenes resultantes o chips (las imágenes son cuadradas)
# * **step-size** paso del proceso. Debe ser menor o igual a *size*. Si *step-size* es igual que el *size* entonces no hay overlap en las imágenes resultantes.
#
# En ocaciones es útil para el entrenamiento generar los chips con un overlap de este modo tenemos más datos para entrenar.
#
#
# * **label-property** nombre del campo donde se define cada categoría (solo se usa para el entrenamiento)
#
# * **classes** nombres de las clases (como aparecen en el geojson), separados por espacios
#
# * **aoi** ruta al archivo vectorial donde están definidas las anotaciones. Al definir una region de interés solo se procesan las imágenes que interceptan esas anotaciones.
#
# * **rescale** lleva los valores de las bandas a 0-255
#
# Este comando va a generar dos carpetas en la ruta de destino : “images” y “extent”. Los archivos de la primera van a ser de tipo Tiff de 3 bandas (rgb) y los de la segunda van a ser, también, de tipo Tiff pero de N bandas donde N representa el número de clases, en este caso sólo una. Y donde cada una de las bandas es una máscara binaria

# %% [markdown]
# ## Entrenamiento
#
# Generamos el entrenamiento del modelo utilizando los datasets creados en el paso previo. El modelo es una red neuronal CNN basado en la arquitectura U-Net. Este considera las imágenes y las máscaras binarias como inputs y genera una imagen con la probabilidad de encontrar al objeto de interés.

# %% [markdown]
# En esta etapa debemos definir la configuración del modelo de ML.

# %%
config = TrainConfig(width   = 160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc; y no menor a 80)
                     height  = 160,
                     n_channels   = 4,  #  número de canales de la imagen, rgb -> 3
                     n_classes    = 1, # número de clases a clasificar
                     apply_image_augmentation = True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes (rotación,)
                     seed       = 42,
                     epochs     = 20, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size = 16, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch  = STEP_PER_EPOCH, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience  = 5, # a medida que entrena se guardan los resultados del entrenamiento despues de cada epoch, si el error no varió luego de ¿¿10 ?? iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split   = 0.1, # se divide la muestra en training (80% de los datos) y validation (20% de los datos) para calcular el error durante el proceso de entrenamiento
                     test_split         = 0.1, # Cantidad de imágenes del dataset
                     images_path        = output_folder,#ruta a las imágenes generadas con Satproc
                     model_path         = os.path.join(BASE_PATH,'data/weights/', MODEL_NAME),#  ruta del modelo entrenado
                     model_architecture = 'unet',
                     evaluate           = True  ,
                     class_weights      = [1])

# %% [markdown]
# *Obs*: Es util usar un nombre para el archivo de pesos que de información sobre los parametros de entrenamiento. por ejemplo: < modelo >_< proyecto >_< dim_de_las_imagenes >_< size >_< step_size >_< step_per_epoch >.h5 o similares

# %% [markdown]
# Podemos visualizar alguna de las imágenes y máscaras del dataset de entrenamiento. A la izquierda se muestra la imágen y a la derecha la máscara

# %%
plot_data_generator(num_samples=3, fig_size=(20, 20), train_config=config)

# %% [markdown]
# Corremos el entrenamiento.

# %%
res_config = train(config)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 160, 160, 4) 0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 160, 160, 32) 1184        input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 160, 160, 32) 9248        conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 80, 80, 32)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 80, 80, 32)   128         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 80, 80, 64)   18496       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 80, 80, 64)   36928       conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 40, 40, 64)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 40, 40, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 40, 40, 64)   256         dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 40, 40, 128)  73856       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 40, 40, 128)  147584      conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 20, 20, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 20, 20, 128)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 20, 20, 128)  512         dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 20, 20, 256)  295168      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 20, 20, 256)  590080      conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 10, 10, 256)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 10, 10, 256)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 256)  1024        dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 10, 10, 512)  1180160     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 5, 5, 512)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 5, 5, 512)    0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 5, 5, 1024)   4719616     dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 5, 5, 1024)   9438208     conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 10, 10, 512)  2097664     conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 10, 10, 1024) 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 1024) 4096        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 10, 10, 512)  4719104     batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 10, 10, 512)  2359808     conv2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 10, 10, 512)  0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 20, 20, 256)  524544      dropout_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 20, 20, 512)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 20, 20, 512)  2048        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 20, 20, 256)  1179904     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 20, 20, 256)  590080      conv2d_37[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 20, 20, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 40, 40, 128)  131200      dropout_13[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 40, 40, 256)  0           conv2d_transpose_7[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 40, 40, 256)  1024        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 40, 40, 128)  295040      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 40, 40, 128)  147584      conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 40, 40, 128)  0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 80, 80, 64)   32832       dropout_14[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 80, 80, 128)  0           conv2d_transpose_8[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 80, 80, 128)  512         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 80, 80, 64)   73792       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 80, 80, 64)   36928       conv2d_41[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 80, 80, 64)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 160, 160, 32) 8224        dropout_15[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 160, 160, 64) 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 160, 160, 32) 18464       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 160, 160, 32) 9248        conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 160, 160, 1)  33          conv2d_44[0][0]
# ==================================================================================================
# Total params: 31,104,385
# Trainable params: 31,099,585
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 11856
# Num. training images: 9603
# Num. validation images: 1067
# Num. test images: 1186
# Compile and fit the UNet model
# UNet_160x160_sentinel2_4D_classA_v0
# 2022-07-12 16:12:18.386500: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2022-07-12 16:12:18.386529: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2022-07-12 16:12:18.386606: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1415] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI_ERROR_NOT_INITIALIZED
# 2022-07-12 16:12:18.386622: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# Epoch 1/20
#   2/650 [..............................] - ETA: 2:34 - loss: 3.0376 - mean_io_u_1: 0.4937
# 2022-07-12 16:12:21.090593: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2022-07-12 16:12:21.090630: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2022-07-12 16:12:21.090692: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1415] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error CUPTI_ERROR_NOT_INITIALIZED
# 2022-07-12 16:12:21.464818: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2022-07-12 16:12:21.471637: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:228]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-07-12 16:12:21.474365: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2022-07-12 16:12:21.477052: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21
# 2022-07-12 16:12:21.478173: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.trace.json.gz
# 2022-07-12 16:12:21.512310: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21
# 2022-07-12 16:12:21.519343: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.memory_profile.json.gz
# 2022-07-12 16:12:21.519627: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21Dumped tool data for xplane.pb to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.xplane.pb
# Dumped tool data for overview_page.pb to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./../logs/UNet_160x160_sentinel2_4D_classA_v0_Date_12-07-2022_Time_16-12-18/train/plugins/profile/2022_07_12_16_12_21/quilmes-gpu-1.kernel_stats.pb
# 650/650 [==============================] - 200s 305ms/step - loss: 0.1833 - mean_io_u_1: 0.4906 - val_loss: 0.0899 - val_mean_io_u_1: 0.4913
#
# Epoch 00001: val_loss improved from inf to 0.08994, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 2/20
# 650/650 [==============================] - 196s 302ms/step - loss: 0.0830 - mean_io_u_1: 0.4911 - val_loss: 0.0974 - val_mean_io_u_1: 0.4913
#
# Epoch 00002: val_loss did not improve from 0.08994
# Epoch 3/20
# 650/650 [==============================] - 196s 301ms/step - loss: 0.0808 - mean_io_u_1: 0.4910 - val_loss: 0.0811 - val_mean_io_u_1: 0.4918
#
# Epoch 00003: val_loss improved from 0.08994 to 0.08113, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 4/20
# 650/650 [==============================] - 197s 303ms/step - loss: 0.0821 - mean_io_u_1: 0.4907 - val_loss: 0.0728 - val_mean_io_u_1: 0.4918
#
# Epoch 00004: val_loss improved from 0.08113 to 0.07284, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 5/20
# 650/650 [==============================] - 197s 304ms/step - loss: 0.0774 - mean_io_u_1: 0.4909 - val_loss: 0.0787 - val_mean_io_u_1: 0.4913
#
# Epoch 00005: val_loss did not improve from 0.07284
# Epoch 6/20
# 650/650 [==============================] - 196s 301ms/step - loss: 0.0759 - mean_io_u_1: 0.4908 - val_loss: 0.0842 - val_mean_io_u_1: 0.4917
#
# Epoch 00006: val_loss did not improve from 0.07284
# Epoch 7/20
# 650/650 [==============================] - 196s 302ms/step - loss: 0.0713 - mean_io_u_1: 0.4915 - val_loss: 0.0772 - val_mean_io_u_1: 0.4905
#
# Epoch 00007: val_loss did not improve from 0.07284
# Epoch 8/20
# 650/650 [==============================] - 198s 305ms/step - loss: 0.0744 - mean_io_u_1: 0.4910 - val_loss: 0.0715 - val_mean_io_u_1: 0.4920
#
# Epoch 00008: val_loss improved from 0.07284 to 0.07149, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 9/20
# 650/650 [==============================] - 198s 304ms/step - loss: 0.0697 - mean_io_u_1: 0.4914 - val_loss: 0.0970 - val_mean_io_u_1: 0.4908
#
# Epoch 00009: val_loss did not improve from 0.07149
# Epoch 10/20
# 650/650 [==============================] - 196s 302ms/step - loss: 0.0737 - mean_io_u_1: 0.4909 - val_loss: 0.0682 - val_mean_io_u_1: 0.4910
#
# Epoch 00010: val_loss improved from 0.07149 to 0.06823, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 11/20
# 650/650 [==============================] - 198s 304ms/step - loss: 0.0759 - mean_io_u_1: 0.4901 - val_loss: 0.0641 - val_mean_io_u_1: 0.4920
#
# Epoch 00011: val_loss improved from 0.06823 to 0.06406, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 12/20
# 650/650 [==============================] - 197s 303ms/step - loss: 0.0700 - mean_io_u_1: 0.4912 - val_loss: 0.0631 - val_mean_io_u_1: 0.4926
#
# Epoch 00012: val_loss improved from 0.06406 to 0.06305, saving model to ./../data/weights/UNet_160x160_sentinel2_4D_classA_v0.h5
# Epoch 13/20
# 650/650 [==============================] - 198s 304ms/step - loss: 0.0668 - mean_io_u_1: 0.4912 - val_loss: 0.1459 - val_mean_io_u_1: 0.4898
#
# Epoch 00013: val_loss did not improve from 0.06305
# Epoch 14/20
# 650/650 [==============================] - 198s 304ms/step - loss: 0.0652 - mean_io_u_1: 0.4913 - val_loss: 0.0903 - val_mean_io_u_1: 0.4919
#
# Epoch 00014: val_loss did not improve from 0.06305
# Epoch 15/20
# 650/650 [==============================] - 200s 308ms/step - loss: 0.0704 - mean_io_u_1: 0.4909 - val_loss: 0.0721 - val_mean_io_u_1: 0.4907
#
# Epoch 00015: val_loss did not improve from 0.06305
# Epoch 16/20
# 650/650 [==============================] - 198s 305ms/step - loss: 0.0686 - mean_io_u_1: 0.4908 - val_loss: 0.0781 - val_mean_io_u_1: 0.4909
#
# Epoch 00016: val_loss did not improve from 0.06305
# Epoch 17/20
# 650/650 [==============================] - 197s 303ms/step - loss: 0.0671 - mean_io_u_1: 0.4915 - val_loss: 0.0674 - val_mean_io_u_1: 0.4914
#
# Epoch 00017: val_loss did not improve from 0.06305
# Epoch 00017: early stopping
# 75/75 [==============================] - 20s 264ms/step - loss: 0.0662 - mean_io_u_1: 0.4914
# *** Final  metrics ***
# Loss: 0.06622674316167831
# Mean IoU: 0.4913514256477356

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
#%tensorboard --logdir ../logs

# %% [markdown]
# Graficamos las métricas generadas.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))

plt.subplot(121)
plt.plot(res_config.history['loss'])
plt.plot(res_config.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(122)
plt.plot(res_config.history['mean_io_u_2'])
plt.plot(res_config.history['val_mean_io_u_2'])
plt.title('mean_iou')
plt.ylabel('val_mean_iou')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')


plt.show()

# %%
# !gsutil -m cp -r $config.model_path $BUCKET_MODEL
